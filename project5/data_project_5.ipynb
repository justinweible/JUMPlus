# %% [markdown]
# ### JUMPlus Data Project 5

# %% [markdown]
# #### Import Statements and Importing the CSV

# %%
import pandas as pd
from datetime import datetime as dt

# %%
purchases_df = pd.read_csv("../project5/CSV/Ecommerce_purchases.csv")

# %% [markdown]
# #### 1. Display Top 10 Rows of The Dataset

# %%
purchases_df.head(10)
# Out:
#                                              Address    Lot AM or PM
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM  \
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6   93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8          2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9  3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  \
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# #### 2. Check Last 10 Rows of The Dataset

# %%
purchases_df.tail(10)
# Out:
#                                                 Address    Lot AM or PM
# 9990  75731 Molly Springs\r\nWest Danielle, VT 96934...  93 ty       PM  \
# 9991            PSC 8165, Box 8498\r\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\r\nWallhaven, LA ...  40 vH       PM
# 9993  7555 Larson Locks Suite 229\r\nEllisburgh, MA ...  72 jg       PM
# 9994     6276 Rojas Hollow\r\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995    966 Castaneda Locks\r\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
# 9997            Unit 4434 Box 6343\r\nDPO AE 28026-0283  74 Zh       AM
# 9998             0096 English Rest\r\nRoystad, IA 12457  74 cL       PM
# 9999   40674 Barrett Stravenue\r\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...  \
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# ##### 3. Check Datatype of Each Column

# %%
purchases_df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# ##### 4. Check null values in the dataset.

# %%
purchases_df.isna().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# #### 5. How many rows and columns are there in our Dataset?

# %%
row_count = purchases_df.shape[0]
print("Row Count of DF: {}".format(row_count))
# Out:
# Row Count of DF: 10000

# %%
column_count = purchases_df.shape[1]
print("Column Count of DF: {}".format(column_count))
# Out:
# Column Count of DF: 14

# %% [markdown]
# #### 6. Show all columns first then find the length of them.

# %%
purchases_df.columns.to_list()
# Out:
# ['Address',
#  'Lot',
#  'AM or PM',
#  'Browser Info',
#  'Company',
#  'Credit Card',
#  'CC Exp Date',
#  'CC Security Code',
#  'CC Provider',
#  'Email',
#  'Job',
#  'IP Address',
#  'Language',
#  'Purchase Price']

# %%
column_length = len(purchases_df.columns)
print("Length of columns in the dataset: {}".format(column_length))
# Out:
# Length of columns in the dataset: 14

# %% [markdown]
# #### 7. Show all number of rows

# %%
row_length = len(purchases_df.index)
print("All number of rows: {}".format(row_length))
# Out:
# All number of rows: 10000

# %% [markdown]
# #### 8. Show complete information of dataset.

# %%
purchases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# #### 9. Show Highest and Lowest Purchase Prices.

# %%
# Highest purchase price
purchases_df.loc[purchases_df['Purchase Price'].idxmax()]
# Out:
# Address                   63773 Shelton Greens\r\nAshleyton, MA 00493
# Lot                                                             56 lu
# AM or PM                                                           AM
# Browser Info        Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Company                                                   Pitts Group
# Credit Card                                             4292741269160
# CC Exp Date                                                     06/18
# CC Security Code                                                  824
# CC Provider                                                   Maestro
# Email                                        heatherwoodard@lloyd.com
# Job                                            Surveyor, hydrographic
# IP Address                                            172.197.216.229
# Language                                                           el
# ...

# %%
# Lowest purchase price
purchases_df.loc[purchases_df['Purchase Price'].idxmin()]
# Out:
# Address             332 Jones Parkways\r\nEast Katherineville, GA ...
# Lot                                                             39 GT
# AM or PM                                                           AM
# Browser Info        Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# Company                                         Lyons, Diaz and Clark
# Credit Card                                          4204500444841766
# CC Exp Date                                                     01/18
# CC Security Code                                                   38
# CC Provider                                             VISA 16 digit
# Email                                            jennifer11@baker.com
# Job                                              Biomedical scientist
# IP Address                                             223.47.177.174
# Language                                                           it
# ...

# %% [markdown]
# #### 10. Show average purchase price

# %%
average_purchase_price = purchases_df["Purchase Price"].mean()
print('Average Purchase Price: {}'.format(average_purchase_price))
# Out:
# Average Purchase Price: 50.347302

# %% [markdown]
# #### 11. How many people have French 'fr' as their Language?

# %%
language_df = purchases_df.loc[purchases_df["Language"] == "fr"]
language_df.head(10)
# Out:
#                                               Address    Lot AM or PM
# 1   9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM  \
# 19              125 Hall Summit\r\nBoothton, IL 41721  99 CU       PM
# 53            PSC 9431, Box 7059\r\nAPO AA 29285-1363  14 qD       AM
# 76  49206 Campbell Port\r\nNorth Cliffordshire, HI...  71 iu       PM
# 82  493 Smith Valleys Suite 004\r\nNew Madelinevil...  35 ls       PM
# 84       392 Smith Squares\r\nWest Nicholas, UT 18079  68 Cs       PM
# 91        874 Tanner Islands\r\nJosephhaven, ND 47343  64 Aj       AM
# 95  4445 Christopher Well Apt. 053\r\nRonaldton, K...  33 Uu       PM
# 96  17923 Carol Lake Suite 232\r\nNew Andre, MD 05...  20 bk       AM
# 98  192 Malone Stream Suite 756\r\nLake Gary, KS 3...  00 zU       AM
#
#                                          Browser Info
# 1   Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...  \
# 19  Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# ...

# %%
french_speakers = language_df.shape[0]
print("Number of French speakers: {}".format(french_speakers))
# Out:
# Number of French speakers: 1097

# %% [markdown]
# #### 12. Find Job Title Contains Engineer word

# %%
engineers = purchases_df.loc[purchases_df['Job']
                             .str.contains("engineer", case=False)]
engineers.head(10)
# Out:
#                                                Address    Lot AM or PM
# 1    9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM  \
# 3              7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 50   41159 Michael Centers\r\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55   27635 Maureen Bypass Apt. 883\r\nSandraview, S...  59 LJ       AM
# 60   7126 Katherine Squares\r\nPerkinsview, CO 9729...  63 qu       AM
# 64   937 Weaver Isle Apt. 096\r\nTracyborough, KY 1...  97 QO       AM
# 82   493 Smith Valleys Suite 004\r\nNew Madelinevil...  35 ls       PM
# 92             Unit 9659 Box 0618\r\nDPO AA 00377-5360  37 jN       AM
# 98   192 Malone Stream Suite 756\r\nLake Gary, KS 3...  00 zU       AM
# 103             480 Ronald Cape\r\nJohnville, MA 53644  11 wg       AM
#
#                                           Browser Info
# 1    Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...  \
# 3    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# ...

# %%
engineer_count = engineers.shape[0]
print("Number of Engineers: {}".format(engineer_count))
# Out:
# Number of Engineers: 984

# %% [markdown]
# #### 12. Find The Email of the person with the following IP Address: 132.207.160.22

# %%
# Display full row
ip_address = purchases_df.loc[purchases_df['IP Address'] == "132.207.160.22"]
ip_address
# Out:
#                               Address    Lot AM or PM
# 2  Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM  \
#
#                                         Browser Info
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...  \
#
#                       Company   Credit Card CC Exp Date  CC Security Code
# 2  Simpson, Williams and Pham  675957666125       08/19               699  \
#
#     CC Provider                           Email                       Job
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager  \
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
# Display just the e-mail address
ip_address['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# #### 14. How many People have Mastercard as their Credit Card Provider and made a purchase above 50 dollars?

# %%
mc_customers = purchases_df.loc[(purchases_df["CC Provider"]=='Mastercard') 
                                & (purchases_df["Purchase Price"] > 50)]

# %%
mc_customers = mc_customers[['Address', 'Company', 'CC Provider', 'Email', 'Purchase Price']]

# %%
mc_customers.head(10)
# Out:
#                                                Address
# 1    9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  \
# 18   461 Christopher Square\r\nWest Michaelchester,...
# 31                  USNS Alvarado\r\nFPO AA 27052-1231
# 35   93392 Webb Gardens Apt. 220\r\nLaurabury, AR 9...
# 90       431 Bowen Lights\r\nFergusonborough, MH 01362
# 120  70617 Robert Bypass\r\nNorth Anita, AR 86445-2370
# 121  54190 Kimberly Garden\r\nMichealstad, MT 73821...
# 127                 PSC 3209, Box 6106\r\nAPO AE 45267
# 159            PSC 1717, Box 9046\r\nAPO AP 75015-9066
# 166      8991 Sutton Unions\r\nDiazview, TN 65790-2439
#
#                              Company CC Provider
# 1    Fletcher, Richards and Whitaker  Mastercard  \
# 18            Beard, Abbott and Pena  Mastercard
# 31                   Nicholson Group  Mastercard
# 35                          Mora Ltd  Mastercard
# 90                      Copeland-Lee  Mastercard
# 120                      Green-Jones  Mastercard
# ...

# %%
mc_customer_count = mc_customers.shape[0]
print("Number of Mastercard Customers who made purchases of more than 50 dollars: {}"
      .format(mc_customer_count))
# Out:
# Number of Mastercard Customers who made purchases of more than 50 dollars: 405

# %% [markdown]
# #### 15. Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
cc_number = 4664825258997302
individual_customer = purchases_df.loc[(purchases_df['Credit Card'] == cc_number)]
individual_customer['Email']
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# #### 16. How many people purchase during the AM and how many people purchase during PM?

# %%
time_of_day_df = purchases_df['AM or PM']
time_of_day_df
# Out:
# 0       PM
# 1       PM
# 2       PM
# 3       PM
# 4       AM
#         ..
# 9995    PM
# 9996    AM
# 9997    AM
# 9998    PM
# 9999    AM
# Name: AM or PM, Length: 10000, dtype: object

# %%
time_of_day_df.value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# #### 17. How many people have a credit card that expires in 2020?

# %%
purchases_df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
purchases_df['CC Exp Date'] = pd.to_datetime(purchases_df['CC Exp Date'], format='%m/%y')

# %%
purchases_df['CC Exp Date'] = purchases_df['CC Exp Date'].dt.strftime('%m/%Y')
purchases_df.head(10)
# Out:
#                                              Address    Lot AM or PM
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM  \
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6   93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8          2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9  3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  \
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
purchases_df['Year'] = purchases_df['CC Exp Date'].str.split('/').str[-1]
purchases_df.head(10)
# Out:
#                                              Address    Lot AM or PM
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM  \
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6   93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8          2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9  3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  \
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
purchases_df['Year'].value_counts()
# Out:
# Year
# 2025    1033
# 2023    1010
# 2021    1006
# 2022     996
# 2018     995
# 2019     995
# 2024     992
# 2020     988
# 2017     955
# 2026     654
# 2016     376
# Name: count, dtype: int64

# %%
year_df = purchases_df.loc[purchases_df['Year']=='2020']

# %%
year_count = year_df['Year'].count()
print("Number of people who have credit cards that expire in 2020: {}".format(year_count))
# Out:
# Number of people who have credit cards that expire in 2020: 988

# %% [markdown]
# #### 18. What are the top 5 most popular email providers (e.g. Gmail.com, yahoo.com, etc...)

# %%
purchases_df['Email Provider'] = purchases_df['Email'].str.split('@').str[-1]
purchases_df.head(10)
# Out:
#                                              Address    Lot AM or PM
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM  \
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                 Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3            7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6   93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8          2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9  3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  \
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
purchases_df['Email Provider'].value_counts().head(5)
# Out:
# Email Provider
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
